# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
avocado = pd.read_csv('datasets/avocado_2015_to_2020.csv')

# %%
avocado.head()
# Out:
#    AveragePrice  Total Volume     4046      4225     4770  Total Bags  \
# 0          1.75      27365.89  9307.34   3844.81   615.28    13598.46
# 1          1.49      17723.17  1189.35  15628.27     0.00      905.55
# 2          1.68       2896.72   161.68    206.96     0.00     2528.08
# 3          1.52      54956.80  3013.04  35456.88  1561.70    14925.18
# 4          1.64       1505.12     1.27   1129.50     0.00      374.35
#
#    Small Bags  Large Bags  XLarge Bags          Type  Year  \
# 0    13061.10      537.36          0.0       Organic  2015
# 1      905.55        0.00          0.0       Organic  2015
# 2     2528.08        0.00          0.0       Organic  2015
# 3    11264.80     3660.38          0.0  Conventional  2015
# 4      186.67      187.68          0.0       Organic  2015
#
#                Region Month
# 0           Southeast   Jan
# 1             Chicago   Jan
# 2  HarrisburgScranton   Jan
# 3          Pittsburgh   Jan
# 4               Boise   Jan

# %%
avocado.tail()
# Out:
#        AveragePrice  Total Volume      4046      4225     4770  Total Bags  \
# 29584          1.71     319478.21  10238.36  29135.42  1436.43   278668.00
# 29585          1.63      28991.82   1307.40   1007.02  3007.50    23669.90
# 29586          1.72      16063.00   1632.59   1111.49  2203.91    11115.01
# 29587          1.67      26787.67    721.03    920.86  4109.45    21036.33
# 29588          1.60      24544.94    638.96    693.39  2963.42    20249.17
#
#        Small Bags  Large Bags  XLarge Bags     Type  Year            Region  \
# 29584   142226.87   136277.55       163.58  Organic  2020              West
# 29585    18937.02     4732.88         0.00  Organic  2020  WestTexNewMexico
# 29586     6040.80     5074.21         0.00  Organic  2020  WestTexNewMexico
# 29587    15924.92     5111.41         0.00  Organic  2020  WestTexNewMexico
# 29588    17197.35     3051.82         0.00  Organic  2020  WestTexNewMexico
#
#       Month
# 29584   Mar
# 29585   Apr
# 29586   Apr
# ...

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29589 entries, 0 to 29588
# Data columns (total 13 columns):
# AveragePrice    29589 non-null float64
# Total Volume    29589 non-null float64
# 4046            29589 non-null float64
# 4225            29589 non-null float64
# 4770            29589 non-null float64
# Total Bags      29589 non-null float64
# Small Bags      29589 non-null float64
# Large Bags      29589 non-null float64
# XLarge Bags     29589 non-null float64
# Type            29589 non-null object
# Year            29589 non-null int64
# Region          29589 non-null object
# Month           29589 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 2.9+ MB

# %%
avocado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  29589.000000  2.958900e+04  2.958900e+04  2.958900e+04  2.958900e+04
# mean       1.391560  9.321374e+05  2.974697e+05  2.851481e+05  2.167614e+04
# std        0.382338  3.779922e+06  1.281411e+06  1.170059e+06  1.011656e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.110000  1.413107e+04  7.815300e+02  2.818980e+03  0.000000e+00
# 50%        1.360000  1.232202e+05  1.038227e+04  2.467599e+04  1.872000e+02
# 75%        1.630000  4.870247e+05  1.142002e+05  1.414425e+05  5.482350e+03
# max        3.250000  6.371614e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags   XLarge Bags          Year
# count  2.958900e+04  2.958900e+04  2.958900e+04  2.958900e+04  29589.000000
# mean   3.277594e+05  2.286121e+05  9.316253e+04  5.984796e+03   2017.164318
# ...

# %%
plt.figure(figsize=(15, 10))
sns.pointplot(x = 'Year' , y = 'AveragePrice' , data = avocado , hue = 'Month' , ci = False , palette= sns.color_palette('Set2'))
plt.show()

# %%
avog = avocado.groupby('Month')['Type'].value_counts()

# %%
avocado['Type'].value_counts()
# Out:
# Conventional    14796
# Organic         14793
# Name: Type, dtype: int64
